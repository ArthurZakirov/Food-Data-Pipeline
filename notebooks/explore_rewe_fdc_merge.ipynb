# %%
import pandas as pd

path = "../data/processed/merge_rewe_fdc_50_percent.csv"

df = pd.read_csv(path)
df
# Out:
#                             Non Nutrient Data.Image URL  \
# 0     https://img.rewe-static.de/1033906/23292477_di...
# 1     https://img.rewe-static.de/1930502/24568902_di...
# 2     https://img.rewe-static.de/1098629/23731060_di...
# 3     https://img.rewe-static.de/7158570/39459560_di...
# 4     https://img.rewe-static.de/4571894/31072971_di...
# ...                                                 ...
# 1335  https://img.rewe-static.de/8287926/42670720_di...
# 1336  https://img.rewe-static.de/8644883/35532057_di...
# 1337  https://img.rewe-static.de/5356784/2108430_dig...
# 1338  https://img.rewe-static.de/7152389/32161059_di...
# 1339  https://img.rewe-static.de/8826343/36666364_di...
#
#                     Non Nutrient Data.Original Name Non Nutrient Data.Unit  \
# 0                           Cherry Romatomaten 250g                   100g
# 1                               Bio Banane ca. 200g                   100g
# ...
